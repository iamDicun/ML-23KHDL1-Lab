# %%
from crawl_hotel_urls import crawl_hotel_urls

# %%
crawl_hotel_urls()
# Out:
# ...
# AGODA HOTEL URL CRAWLER - ĐÀ NẴNG
# ...
#
# [1] Initializing Chrome WebDriver...
#
# [2] Navigating to search page...
#
# [3] Waiting for page to load...
#
# [4] Crawling hotels page by page...
#     Progress saved automatically after each page.
#
#
#     --- Page 1 ---
#     Starting scroll... (initial: 11 cards)
#     Scroll 2: +38 cards (total: 49)
#     Scroll 8: +49 cards (total: 98)
#     ✓ Reached bottom of page (98 cards)
#     Found 98 hotels on page 1
#     Extracted 98 new hotels (Total: 98)
#     ✓ Checkpoint saved
#     → Navigating to page 2...
#
#     --- Page 2 ---
#     Starting scroll... (initial: 0 cards)
#     Scroll 1: +49 cards (total: 49)
#     Scroll 8: +49 cards (total: 98)
#     ✓ Reached bottom of page (98 cards)
#     Found 98 hotels on page 2
#     Extracted 98 new hotels (Total: 196)
#     ✓ Checkpoint saved
#     → Navigating to page 3...
#
#     --- Page 3 ---
#     Starting scroll... (initial: 0 cards)
#     Scroll 1: +49 cards (total: 49)
# ...
