# %%
import sys, os

base = "/kaggle/input/datasets/nguyenan2511/hotel-absa-model-code"
sys.path.insert(0, base)
print("Import OK")
# Out:
# Import OK

# %%
import tqdm
import tqdm.notebook
import sys

tqdm.tqdm = tqdm.notebook.tqdm

sys.argv = [
    "train.py",
    "--train-csv", "/kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_train.csv",
    "--val-csv",   "/kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_val.csv",
    "--model-dir", "/kaggle/working/models_final",
    "--unfreeze-layers", "2",
    "--encoder-lr", "5e-5",
    "--amp",
]

from model.train import train
train()
# Out:
# 2026-04-12 16:58:38,667 - model.train - INFO - Mixed precision training (AMP) enabled
# 2026-04-12 16:58:38,668 - model.data - INFO - Verifying label values in: /kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_train.csv
# 2026-04-12 16:58:38,765 - model.data - INFO - Label validation passed: all labels are in [0, 2]
# 2026-04-12 16:58:38,968 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 16:58:38,984 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/config.json "HTTP/1.1 200 OK"
# 2026-04-12 16:58:39,057 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 16:58:39,074 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-12 16:58:39,171 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-04-12 16:58:39,241 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-04-12 16:58:40,454 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base "HTTP/1.1 200 OK"
# 2026-04-12 16:58:40,465 - model.data - INFO - Loading reviews from: /kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_train.csv
# 2026-04-12 16:58:40,551 - model.data - INFO - Loaded 13224 reviews
# 2026-04-12 16:58:40,552 - model.data - INFO - Loading reviews from: /kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_val.csv
# 2026-04-12 16:58:40,582 - model.data - INFO - Loaded 3778 reviews
# 2026-04-12 16:58:44,577 - model.data - INFO - Pre-tokenized 13224 samples in 3.99s
# 2026-04-12 16:58:45,857 - model.data - INFO - Pre-tokenized 3778 samples in 1.14s
# 2026-04-12 16:58:45,908 - model.train - INFO - Class weights:
# 2026-04-12 16:58:45,910 - model.train - INFO -   hygiene: ['0.688', '1.182', '2.408']
# 2026-04-12 16:58:45,910 - model.train - INFO -   food: ['0.634', '1.596', '2.876']
# 2026-04-12 16:58:45,911 - model.train - INFO -   hotel: ['1.191', '0.697', '2.057']
# 2026-04-12 16:58:45,911 - model.train - INFO -   location: ['0.723', '0.989', '3.961']
# 2026-04-12 16:58:45,912 - model.train - INFO -   room: ['0.759', '1.061', '1.632']
# 2026-04-12 16:58:45,913 - model.train - INFO -   service: ['0.799', '0.873', '2.844']
# 2026-04-12 16:58:45,913 - model.hf_videberta - INFO - Loading model: Fsoft-AIC/videberta-base
# 2026-04-12 16:58:46,036 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 16:58:46,055 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/config.json "HTTP/1.1 200 OK"
# 2026-04-12 16:58:46,143 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-12 16:58:46,144 - huggingface_hub.utils._http - WARNING - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-12 16:58:46,161 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/config.json "HTTP/1.1 200 OK"
# 2026-04-12 16:58:46,232 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/pytorch_model.bin "HTTP/1.1 302 Found"
# 2026-04-12 16:58:46,298 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/xet-read-token/a27c8175098cc2b2b55585763fe26c60b117804c "HTTP/1.1 200 OK"
# pytorch_model.bin:   0%|          | 0.00/567M [00:00<?, ?B/s]
# 2026-04-12 16:58:49,426 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# 2026-04-12 16:58:49,520 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base "HTTP/1.1 200 OK"
# 2026-04-12 16:58:49,620 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/commits/main "HTTP/1.1 200 OK"
# 2026-04-12 16:58:49,726 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/discussions?p=0 "HTTP/1.1 200 OK"
# 2026-04-12 16:58:49,808 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/commits/refs%2Fpr%2F1 "HTTP/1.1 200 OK"
# 2026-04-12 16:58:49,878 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/refs%2Fpr%2F1/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 2026-04-12 16:58:49,946 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/refs%2Fpr%2F1/model.safetensors "HTTP/1.1 302 Found"
# 2026-04-12 16:58:50,010 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/xet-read-token/d72e04d6e5065b2babb6bccad6f86960701f0572 "HTTP/1.1 200 OK"
# model.safetensors:   0%|          | 0.00/567M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/198 [00:00<?, ?it/s]
# DebertaV2Model LOAD REPORT from: Fsoft-AIC/videberta-base
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# deberta.embeddings.word_embeddings._weight | UNEXPECTED |  |
# mask_predictions.LayerNorm.bias            | UNEXPECTED |  |
# mask_predictions.LayerNorm.weight          | UNEXPECTED |  |
# mask_predictions.classifier.weight         | UNEXPECTED |  |
# mask_predictions.dense.weight              | UNEXPECTED |  |
# mask_predictions.classifier.bias           | UNEXPECTED |  |
# mask_predictions.dense.bias                | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-04-12 16:58:50,426 - model.hf_videberta - INFO - Model loaded successfully
# 2026-04-12 16:58:53,073 - model.train - INFO - Wrapping model in DataParallel across 2 GPUs: ['Tesla T4', 'Tesla T4']
# 2026-04-12 16:58:53,075 - model.train - INFO - Trainable parameters: 16,627,218
# 2026-04-12 16:58:53,076 - model.train - INFO - Last 2 encoder block(s) use lr=5e-05; heads/adapters/lower blocks use lr=0.0002
# 2026-04-12 16:58:53,077 - model.train - INFO - Early stopping patience: 3 epochs
# epoch 1/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:02:00,981 - model.train - INFO - epoch 1 train_loss=1.1378 time=187.9s (3.1min)
# 2026-04-12 17:02:46,205 - model.train - INFO - val loss=0.7976 macro-F1=0.3963
# 2026-04-12 17:02:46,206 - model.train - INFO -   hygiene: 0.4410
# 2026-04-12 17:02:46,206 - model.train - INFO -   food: 0.3312
# 2026-04-12 17:02:46,207 - model.train - INFO -   hotel: 0.3446
# 2026-04-12 17:02:46,208 - model.train - INFO -   location: 0.2714
# 2026-04-12 17:02:46,208 - model.train - INFO -   room: 0.4482
# 2026-04-12 17:02:46,209 - model.train - INFO -   service: 0.5413
# 2026-04-12 17:02:47,251 - model.train - INFO - saved checkpoint macro-F1=0.3963 -> /kaggle/working/models_final/best.pt
# epoch 2/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:05:55,657 - model.train - INFO - epoch 2 train_loss=1.0837 time=188.4s (3.1min)
# 2026-04-12 17:06:40,508 - model.train - INFO - val loss=0.7434 macro-F1=0.4607
# 2026-04-12 17:06:40,509 - model.train - INFO -   hygiene: 0.4966
# 2026-04-12 17:06:40,509 - model.train - INFO -   food: 0.3479
# 2026-04-12 17:06:40,510 - model.train - INFO -   hotel: 0.4872
# 2026-04-12 17:06:40,511 - model.train - INFO -   location: 0.2590
# 2026-04-12 17:06:40,512 - model.train - INFO -   room: 0.5405
# 2026-04-12 17:06:40,513 - model.train - INFO -   service: 0.6332
# 2026-04-12 17:06:42,154 - model.train - INFO - saved checkpoint macro-F1=0.4607 -> /kaggle/working/models_final/best.pt
# epoch 3/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:09:50,876 - model.train - INFO - epoch 3 train_loss=0.9647 time=188.7s (3.1min)
# 2026-04-12 17:10:35,759 - model.train - INFO - val loss=0.6164 macro-F1=0.5696
# 2026-04-12 17:10:35,760 - model.train - INFO -   hygiene: 0.7115
# 2026-04-12 17:10:35,761 - model.train - INFO -   food: 0.3769
# 2026-04-12 17:10:35,762 - model.train - INFO -   hotel: 0.4368
# 2026-04-12 17:10:35,763 - model.train - INFO -   location: 0.4557
# 2026-04-12 17:10:35,764 - model.train - INFO -   room: 0.6906
# 2026-04-12 17:10:35,764 - model.train - INFO -   service: 0.7464
# 2026-04-12 17:10:37,399 - model.train - INFO - saved checkpoint macro-F1=0.5696 -> /kaggle/working/models_final/best.pt
# epoch 4/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:13:45,670 - model.train - INFO - epoch 4 train_loss=0.8725 time=188.3s (3.1min)
# 2026-04-12 17:14:30,555 - model.train - INFO - val loss=0.4692 macro-F1=0.6520
# 2026-04-12 17:14:30,556 - model.train - INFO -   hygiene: 0.7161
# 2026-04-12 17:14:30,556 - model.train - INFO -   food: 0.6588
# 2026-04-12 17:14:30,557 - model.train - INFO -   hotel: 0.5179
# 2026-04-12 17:14:30,558 - model.train - INFO -   location: 0.5841
# 2026-04-12 17:14:30,558 - model.train - INFO -   room: 0.6730
# 2026-04-12 17:14:30,559 - model.train - INFO -   service: 0.7624
# 2026-04-12 17:14:32,152 - model.train - INFO - saved checkpoint macro-F1=0.6520 -> /kaggle/working/models_final/best.pt
# epoch 5/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:17:40,509 - model.train - INFO - epoch 5 train_loss=0.8250 time=188.3s (3.1min)
# 2026-04-12 17:18:25,333 - model.train - INFO - val loss=0.4606 macro-F1=0.6545
# 2026-04-12 17:18:25,334 - model.train - INFO -   hygiene: 0.6952
# 2026-04-12 17:18:25,335 - model.train - INFO -   food: 0.7229
# 2026-04-12 17:18:25,336 - model.train - INFO -   hotel: 0.4546
# 2026-04-12 17:18:25,337 - model.train - INFO -   location: 0.5839
# 2026-04-12 17:18:25,337 - model.train - INFO -   room: 0.7055
# 2026-04-12 17:18:25,338 - model.train - INFO -   service: 0.7647
# 2026-04-12 17:18:26,915 - model.train - INFO - saved checkpoint macro-F1=0.6545 -> /kaggle/working/models_final/best.pt
# epoch 6/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:21:35,124 - model.train - INFO - epoch 6 train_loss=0.7829 time=188.2s (3.1min)
# 2026-04-12 17:22:20,037 - model.train - INFO - val loss=0.4246 macro-F1=0.7117
# 2026-04-12 17:22:20,038 - model.train - INFO -   hygiene: 0.7961
# 2026-04-12 17:22:20,039 - model.train - INFO -   food: 0.7495
# 2026-04-12 17:22:20,039 - model.train - INFO -   hotel: 0.5085
# 2026-04-12 17:22:20,040 - model.train - INFO -   location: 0.6457
# 2026-04-12 17:22:20,041 - model.train - INFO -   room: 0.7741
# 2026-04-12 17:22:20,041 - model.train - INFO -   service: 0.7961
# 2026-04-12 17:22:21,652 - model.train - INFO - saved checkpoint macro-F1=0.7117 -> /kaggle/working/models_final/best.pt
# epoch 7/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:25:30,587 - model.train - INFO - epoch 7 train_loss=0.7601 time=188.9s (3.1min)
# 2026-04-12 17:26:15,473 - model.train - INFO - val loss=0.4499 macro-F1=0.7061
# 2026-04-12 17:26:15,474 - model.train - INFO -   hygiene: 0.7814
# 2026-04-12 17:26:15,475 - model.train - INFO -   food: 0.7651
# 2026-04-12 17:26:15,475 - model.train - INFO -   hotel: 0.4776
# 2026-04-12 17:26:15,475 - model.train - INFO -   location: 0.6366
# 2026-04-12 17:26:15,476 - model.train - INFO -   room: 0.7876
# 2026-04-12 17:26:15,477 - model.train - INFO -   service: 0.7882
# 2026-04-12 17:26:15,477 - model.train - INFO - no improvement (1/3)
# epoch 8/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:29:23,449 - model.train - INFO - epoch 8 train_loss=0.8094 time=188.0s (3.1min)
# 2026-04-12 17:30:08,311 - model.train - INFO - val loss=0.3972 macro-F1=0.7575
# 2026-04-12 17:30:08,312 - model.train - INFO -   hygiene: 0.8186
# 2026-04-12 17:30:08,312 - model.train - INFO -   food: 0.7820
# 2026-04-12 17:30:08,313 - model.train - INFO -   hotel: 0.5610
# 2026-04-12 17:30:08,314 - model.train - INFO -   location: 0.7445
# 2026-04-12 17:30:08,315 - model.train - INFO -   room: 0.8085
# 2026-04-12 17:30:08,315 - model.train - INFO -   service: 0.8304
# 2026-04-12 17:30:09,940 - model.train - INFO - saved checkpoint macro-F1=0.7575 -> /kaggle/working/models_final/best.pt
# epoch 9/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:33:18,291 - model.train - INFO - epoch 9 train_loss=0.7233 time=188.3s (3.1min)
# 2026-04-12 17:34:03,201 - model.train - INFO - val loss=0.3866 macro-F1=0.7674
# 2026-04-12 17:34:03,202 - model.train - INFO -   hygiene: 0.8162
# 2026-04-12 17:34:03,203 - model.train - INFO -   food: 0.8021
# 2026-04-12 17:34:03,203 - model.train - INFO -   hotel: 0.5971
# 2026-04-12 17:34:03,204 - model.train - INFO -   location: 0.7551
# 2026-04-12 17:34:03,205 - model.train - INFO -   room: 0.8153
# 2026-04-12 17:34:03,205 - model.train - INFO -   service: 0.8186
# 2026-04-12 17:34:04,860 - model.train - INFO - saved checkpoint macro-F1=0.7674 -> /kaggle/working/models_final/best.pt
# epoch 10/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:37:13,308 - model.train - INFO - epoch 10 train_loss=0.7031 time=188.4s (3.1min)
# 2026-04-12 17:37:58,211 - model.train - INFO - val loss=0.3657 macro-F1=0.7850
# 2026-04-12 17:37:58,212 - model.train - INFO -   hygiene: 0.8329
# 2026-04-12 17:37:58,212 - model.train - INFO -   food: 0.8165
# 2026-04-12 17:37:58,213 - model.train - INFO -   hotel: 0.6331
# 2026-04-12 17:37:58,214 - model.train - INFO -   location: 0.7773
# 2026-04-12 17:37:58,215 - model.train - INFO -   room: 0.8311
# 2026-04-12 17:37:58,215 - model.train - INFO -   service: 0.8190
# 2026-04-12 17:37:59,851 - model.train - INFO - saved checkpoint macro-F1=0.7850 -> /kaggle/working/models_final/best.pt
# epoch 11/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:41:08,239 - model.train - INFO - epoch 11 train_loss=0.6896 time=188.4s (3.1min)
# 2026-04-12 17:41:53,134 - model.train - INFO - val loss=0.3586 macro-F1=0.8047
# 2026-04-12 17:41:53,134 - model.train - INFO -   hygiene: 0.8364
# 2026-04-12 17:41:53,135 - model.train - INFO -   food: 0.8366
# 2026-04-12 17:41:53,135 - model.train - INFO -   hotel: 0.6508
# 2026-04-12 17:41:53,136 - model.train - INFO -   location: 0.8290
# 2026-04-12 17:41:53,137 - model.train - INFO -   room: 0.8392
# 2026-04-12 17:41:53,138 - model.train - INFO -   service: 0.8361
# 2026-04-12 17:41:54,739 - model.train - INFO - saved checkpoint macro-F1=0.8047 -> /kaggle/working/models_final/best.pt
# epoch 12/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:45:02,777 - model.train - INFO - epoch 12 train_loss=0.6794 time=188.0s (3.1min)
# 2026-04-12 17:45:47,665 - model.train - INFO - val loss=0.3583 macro-F1=0.8029
# 2026-04-12 17:45:47,666 - model.train - INFO -   hygiene: 0.8149
# 2026-04-12 17:45:47,666 - model.train - INFO -   food: 0.8364
# 2026-04-12 17:45:47,668 - model.train - INFO -   hotel: 0.6651
# 2026-04-12 17:45:47,668 - model.train - INFO -   location: 0.8217
# 2026-04-12 17:45:47,669 - model.train - INFO -   room: 0.8373
# 2026-04-12 17:45:47,670 - model.train - INFO -   service: 0.8421
# 2026-04-12 17:45:47,670 - model.train - INFO - no improvement (1/3)
# epoch 13/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:48:55,939 - model.train - INFO - epoch 13 train_loss=0.6681 time=188.3s (3.1min)
# 2026-04-12 17:49:40,728 - model.train - INFO - val loss=0.3513 macro-F1=0.8118
# 2026-04-12 17:49:40,729 - model.train - INFO -   hygiene: 0.8271
# 2026-04-12 17:49:40,730 - model.train - INFO -   food: 0.8441
# 2026-04-12 17:49:40,730 - model.train - INFO -   hotel: 0.6704
# 2026-04-12 17:49:40,731 - model.train - INFO -   location: 0.8365
# 2026-04-12 17:49:40,732 - model.train - INFO -   room: 0.8493
# 2026-04-12 17:49:40,732 - model.train - INFO -   service: 0.8433
# 2026-04-12 17:49:42,366 - model.train - INFO - saved checkpoint macro-F1=0.8118 -> /kaggle/working/models_final/best.pt
# epoch 14/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:52:50,548 - model.train - INFO - epoch 14 train_loss=0.6582 time=188.2s (3.1min)
# 2026-04-12 17:53:35,395 - model.train - INFO - val loss=0.3638 macro-F1=0.8086
# 2026-04-12 17:53:35,396 - model.train - INFO -   hygiene: 0.8102
# 2026-04-12 17:53:35,396 - model.train - INFO -   food: 0.8438
# 2026-04-12 17:53:35,397 - model.train - INFO -   hotel: 0.6653
# 2026-04-12 17:53:35,397 - model.train - INFO -   location: 0.8290
# 2026-04-12 17:53:35,398 - model.train - INFO -   room: 0.8522
# 2026-04-12 17:53:35,399 - model.train - INFO -   service: 0.8508
# 2026-04-12 17:53:35,399 - model.train - INFO - no improvement (1/3)
# epoch 15/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 17:56:43,656 - model.train - INFO - epoch 15 train_loss=0.6509 time=188.2s (3.1min)
# 2026-04-12 17:57:28,522 - model.train - INFO - val loss=0.3467 macro-F1=0.8183
# 2026-04-12 17:57:28,522 - model.train - INFO -   hygiene: 0.8349
# 2026-04-12 17:57:28,523 - model.train - INFO -   food: 0.8473
# 2026-04-12 17:57:28,524 - model.train - INFO -   hotel: 0.6837
# 2026-04-12 17:57:28,524 - model.train - INFO -   location: 0.8521
# 2026-04-12 17:57:28,525 - model.train - INFO -   room: 0.8552
# 2026-04-12 17:57:28,525 - model.train - INFO -   service: 0.8368
# 2026-04-12 17:57:30,147 - model.train - INFO - saved checkpoint macro-F1=0.8183 -> /kaggle/working/models_final/best.pt
# epoch 16/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 18:00:38,543 - model.train - INFO - epoch 16 train_loss=0.6436 time=188.4s (3.1min)
# 2026-04-12 18:01:23,168 - model.train - INFO - val loss=0.3380 macro-F1=0.8201
# 2026-04-12 18:01:23,169 - model.train - INFO -   hygiene: 0.8398
# 2026-04-12 18:01:23,169 - model.train - INFO -   food: 0.8446
# 2026-04-12 18:01:23,170 - model.train - INFO -   hotel: 0.6940
# 2026-04-12 18:01:23,170 - model.train - INFO -   location: 0.8420
# 2026-04-12 18:01:23,171 - model.train - INFO -   room: 0.8519
# 2026-04-12 18:01:23,172 - model.train - INFO -   service: 0.8482
# 2026-04-12 18:01:24,791 - model.train - INFO - saved checkpoint macro-F1=0.8201 -> /kaggle/working/models_final/best.pt
# epoch 17/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 18:04:33,187 - model.train - INFO - epoch 17 train_loss=0.6376 time=188.4s (3.1min)
# 2026-04-12 18:05:17,975 - model.train - INFO - val loss=0.3527 macro-F1=0.8135
# 2026-04-12 18:05:17,976 - model.train - INFO -   hygiene: 0.8282
# 2026-04-12 18:05:17,977 - model.train - INFO -   food: 0.8418
# 2026-04-12 18:05:17,977 - model.train - INFO -   hotel: 0.6769
# 2026-04-12 18:05:17,978 - model.train - INFO -   location: 0.8326
# 2026-04-12 18:05:17,978 - model.train - INFO -   room: 0.8532
# 2026-04-12 18:05:17,979 - model.train - INFO -   service: 0.8483
# 2026-04-12 18:05:17,980 - model.train - INFO - no improvement (1/3)
# epoch 18/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 18:08:26,431 - model.train - INFO - epoch 18 train_loss=0.6333 time=188.4s (3.1min)
# 2026-04-12 18:09:11,293 - model.train - INFO - val loss=0.3445 macro-F1=0.8174
# 2026-04-12 18:09:11,293 - model.train - INFO -   hygiene: 0.8352
# 2026-04-12 18:09:11,294 - model.train - INFO -   food: 0.8388
# 2026-04-12 18:09:11,295 - model.train - INFO -   hotel: 0.6858
# 2026-04-12 18:09:11,296 - model.train - INFO -   location: 0.8399
# 2026-04-12 18:09:11,296 - model.train - INFO -   room: 0.8528
# 2026-04-12 18:09:11,297 - model.train - INFO -   service: 0.8516
# 2026-04-12 18:09:11,298 - model.train - INFO - no improvement (2/3)
# epoch 19/20:   0%|          | 0/414 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# 2026-04-12 18:12:19,300 - model.train - INFO - epoch 19 train_loss=0.6296 time=188.0s (3.1min)
# 2026-04-12 18:13:04,141 - model.train - INFO - val loss=0.3395 macro-F1=0.8194
# 2026-04-12 18:13:04,142 - model.train - INFO -   hygiene: 0.8308
# 2026-04-12 18:13:04,143 - model.train - INFO -   food: 0.8502
# 2026-04-12 18:13:04,144 - model.train - INFO -   hotel: 0.6880
# 2026-04-12 18:13:04,144 - model.train - INFO -   location: 0.8453
# 2026-04-12 18:13:04,145 - model.train - INFO -   room: 0.8514
# 2026-04-12 18:13:04,146 - model.train - INFO -   service: 0.8506
# 2026-04-12 18:13:04,146 - model.train - INFO - no improvement (3/3)
# 2026-04-12 18:13:04,147 - model.train - WARNING - Early stopping triggered at epoch 19: no improvement for 3 epochs. Best macro-F1=0.8201
# 2026-04-12 18:13:04,148 - model.train - INFO - done. best macro-F1=0.8201

# %%
import sys
sys.argv = ["evaluate.py",
            "--checkpoint", "/kaggle/working/models_final/best.pt",
            "--test-csv", "/kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_test.csv"]

from model.evaluate import main
main()
# Out:
# 2026-04-12 18:13:04,827 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 18:13:04,844 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/config.json "HTTP/1.1 200 OK"
# 2026-04-12 18:13:04,918 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 18:13:04,937 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-12 18:13:05,005 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-04-12 18:13:05,109 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-04-12 18:13:06,282 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base "HTTP/1.1 200 OK"
# 2026-04-12 18:13:06,297 - model.data - INFO - Loading reviews from: /kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_test.csv
# 2026-04-12 18:13:06,325 - model.data - INFO - Loaded 1889 reviews
# 2026-04-12 18:13:06,853 - model.data - INFO - Pre-tokenized 1889 samples in 0.52s
# 2026-04-12 18:13:06,873 - model.hf_videberta - INFO - Loading model: Fsoft-AIC/videberta-base
# 2026-04-12 18:13:06,971 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 18:13:06,990 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/config.json "HTTP/1.1 200 OK"
# 2026-04-12 18:13:07,063 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 18:13:07,079 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/config.json "HTTP/1.1 200 OK"
# 2026-04-12 18:13:07,148 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# 2026-04-12 18:13:07,214 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base "HTTP/1.1 200 OK"
# 2026-04-12 18:13:07,295 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/commits/main "HTTP/1.1 200 OK"
# 2026-04-12 18:13:07,375 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/discussions?p=0 "HTTP/1.1 200 OK"
# 2026-04-12 18:13:07,455 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/commits/refs%2Fpr%2F1 "HTTP/1.1 200 OK"
# 2026-04-12 18:13:07,523 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/refs%2Fpr%2F1/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 2026-04-12 18:13:07,590 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/refs%2Fpr%2F1/model.safetensors "HTTP/1.1 302 Found"
# Loading weights:   0%|          | 0/198 [00:00<?, ?it/s]
# DebertaV2Model LOAD REPORT from: Fsoft-AIC/videberta-base
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# deberta.embeddings.word_embeddings._weight | UNEXPECTED |  |
# mask_predictions.LayerNorm.bias            | UNEXPECTED |  |
# mask_predictions.LayerNorm.weight          | UNEXPECTED |  |
# mask_predictions.classifier.weight         | UNEXPECTED |  |
# mask_predictions.dense.weight              | UNEXPECTED |  |
# mask_predictions.classifier.bias           | UNEXPECTED |  |
# mask_predictions.dense.bias                | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-04-12 18:13:07,859 - model.hf_videberta - INFO - Model loaded successfully
# 2026-04-12 18:13:08,675 - model.evaluate - WARNING - Missing keys in checkpoint: ['class_weights']
# 2026-04-12 18:13:08,678 - model.evaluate - INFO -
# --- Model Complexity ---
# 2026-04-12 18:13:08,679 - model.evaluate - INFO - Total parameters:      186,175,506
# 2026-04-12 18:13:08,680 - model.evaluate - INFO - Trainable parameters:   16,627,218  (8.9%)
# 2026-04-12 18:13:08,680 - model.evaluate - INFO - Frozen parameters:     169,548,288  (91.1%)
# 2026-04-12 18:13:08,681 - model.evaluate - INFO - Model size (est.):    710.2 MB (float32)
# 2026-04-12 18:13:46,656 - model.evaluate - INFO -
# Inference time total: 37.98s
# 2026-04-12 18:13:46,657 - model.evaluate - INFO - Inference time per sample: 20.10ms
# 2026-04-12 18:13:46,658 - model.evaluate - INFO - Per-aspect macro-F1 and accuracy:
# 2026-04-12 18:13:46,662 - model.evaluate - INFO -   hygiene: macro-F1=0.8500 acc=0.9269
# 2026-04-12 18:13:46,666 - model.evaluate - INFO -   food: macro-F1=0.8595 acc=0.9576
# 2026-04-12 18:13:46,670 - model.evaluate - INFO -   hotel: macro-F1=0.6924 acc=0.7983
# 2026-04-12 18:13:46,673 - model.evaluate - INFO -   location: macro-F1=0.7889 acc=0.9344
# 2026-04-12 18:13:46,676 - model.evaluate - INFO -   room: macro-F1=0.8578 acc=0.8925
# 2026-04-12 18:13:46,680 - model.evaluate - INFO -   service: macro-F1=0.8420 acc=0.9328
# 2026-04-12 18:13:46,680 - model.evaluate - INFO - Mean macro-F1 (over aspects): 0.8151
