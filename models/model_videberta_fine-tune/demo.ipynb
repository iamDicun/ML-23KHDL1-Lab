# %%
import sys
from infer import main

old_argv = sys.argv[:]
try:
    sys.argv = [
    "infer.py",
    "--text", "khi đến đà_nẵng tôi đã đặt phòng tại một khách_sạn có vị_trí chiến_lược giữa sông và bãi biển và khách_sạn calix là sự lựa_chọn đúng_đắn đồ_ăn ngon nhân_viên đặc_biệt là đoan và một nhân_viên nữ khác đã đón_tiếp tôi rất nồng_nhiệt khi trở về từ hội_an tôi lại đặt phòng tại khách_sạn calix một lần nữa vì vị_trí thuận_lợi giá_cả hợp_lý và đội_ngũ nhân_viên xuất_sắc",
    "--checkpoint", "../../models/best.pt",
    "--json"
    ]
    main()
finally:
    sys.argv = old_argv
# Out:
# 2026-04-13 11:15:38,028 - model.hf_videberta - INFO - Loading model: Fsoft-AIC/videberta-base
# 2026-04-13 11:15:39,269 - model.hf_videberta - INFO - Model loaded successfully
# 2026-04-13 11:15:42,926 - infer - WARNING - Missing keys in checkpoint: ['class_weights']
# {"hygiene": {"prediction": 0, "confidence": 0.8408}, "food": {"prediction": 1, "confidence": 0.9064}, "hotel": {"prediction": 1, "confidence": 0.8312}, "location": {"prediction": 1, "confidence": 0.8431}, "room": {"prediction": 0, "confidence": 0.7005}, "service": {"prediction": 1, "confidence": 0.8062}}
