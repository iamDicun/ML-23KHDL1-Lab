# %%
import sys, os

base = "/kaggle/input/datasets/nguyenan2511/hotel-absa-model-code"
sys.path.insert(0, base)
print("Import OK")
# Out:
# Import OK

# %%
import sys
sys.argv = [
    "train.py",
    "--train-csv", "/kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_train.csv",
    "--val-csv",   "/kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_val.csv",
    "--model-dir", "/kaggle/working/models",
    # "--lr", "1e-4",
]

from model.train import train
train()
# Out:
# 2026-04-12 10:09:30,691 - model.data - INFO - Verifying label values in: /kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_train.csv
# 2026-04-12 10:09:30,783 - model.data - INFO - Label validation passed: all labels are in [0, 2]
# 2026-04-12 10:09:30,954 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 10:09:30,971 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/config.json "HTTP/1.1 200 OK"
# 2026-04-12 10:09:31,032 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 10:09:31,048 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-12 10:09:31,125 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-04-12 10:09:31,225 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-04-12 10:09:32,418 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base "HTTP/1.1 200 OK"
# 2026-04-12 10:09:32,429 - model.data - INFO - Loading reviews from: /kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_train.csv
# 2026-04-12 10:09:32,510 - model.data - INFO - Loaded 13224 reviews
# 2026-04-12 10:09:32,512 - model.data - INFO - Loading reviews from: /kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_val.csv
# 2026-04-12 10:09:32,535 - model.data - INFO - Loaded 3778 reviews
# 2026-04-12 10:09:36,374 - model.data - INFO - Pre-tokenized 13224 samples in 3.83s
# 2026-04-12 10:09:37,588 - model.data - INFO - Pre-tokenized 3778 samples in 1.04s
# 2026-04-12 10:09:37,639 - model.train - INFO - Class weights:
# 2026-04-12 10:09:37,640 - model.train - INFO -   hygiene: ['0.688', '1.182', '2.408']
# 2026-04-12 10:09:37,641 - model.train - INFO -   food: ['0.634', '1.596', '2.876']
# 2026-04-12 10:09:37,642 - model.train - INFO -   hotel: ['1.191', '0.697', '2.057']
# 2026-04-12 10:09:37,642 - model.train - INFO -   location: ['0.723', '0.989', '3.961']
# 2026-04-12 10:09:37,643 - model.train - INFO -   room: ['0.759', '1.061', '1.632']
# 2026-04-12 10:09:37,643 - model.train - INFO -   service: ['0.799', '0.873', '2.844']
# 2026-04-12 10:09:37,644 - model.hf_videberta - INFO - Loading model: Fsoft-AIC/videberta-base
# 2026-04-12 10:09:37,782 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 10:09:37,799 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/config.json "HTTP/1.1 200 OK"
# 2026-04-12 10:09:37,911 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 10:09:37,927 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/config.json "HTTP/1.1 200 OK"
# 2026-04-12 10:09:38,009 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# 2026-04-12 10:09:38,071 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base "HTTP/1.1 200 OK"
# 2026-04-12 10:09:38,145 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/commits/main "HTTP/1.1 200 OK"
# 2026-04-12 10:09:38,246 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/discussions?p=0 "HTTP/1.1 200 OK"
# 2026-04-12 10:09:38,319 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/commits/refs%2Fpr%2F1 "HTTP/1.1 200 OK"
# 2026-04-12 10:09:38,390 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/refs%2Fpr%2F1/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 2026-04-12 10:09:38,455 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/refs%2Fpr%2F1/model.safetensors "HTTP/1.1 302 Found"
# 2026-04-12 10:09:38,531 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/xet-read-token/d72e04d6e5065b2babb6bccad6f86960701f0572 "HTTP/1.1 200 OK"
# model.safetensors:   0%|          | 0.00/567M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/198 [00:00<?, ?it/s]
# DebertaV2Model LOAD REPORT from: Fsoft-AIC/videberta-base
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# mask_predictions.LayerNorm.weight          | UNEXPECTED |  |
# mask_predictions.dense.weight              | UNEXPECTED |  |
# mask_predictions.classifier.weight         | UNEXPECTED |  |
# mask_predictions.LayerNorm.bias            | UNEXPECTED |  |
# deberta.embeddings.word_embeddings._weight | UNEXPECTED |  |
# mask_predictions.dense.bias                | UNEXPECTED |  |
# mask_predictions.classifier.bias           | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-04-12 10:09:38,963 - model.hf_videberta - INFO - Model loaded successfully
# 2026-04-12 10:09:41,671 - model.train - INFO - Wrapping model in DataParallel across 2 GPUs: ['Tesla T4', 'Tesla T4']
# 2026-04-12 10:09:41,674 - model.train - INFO - Early stopping patience: 3 epochs
# epoch 1/10:   0%|          | 0/414 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# epoch 1/10: 100%|██████████| 414/414 [06:00<00:00,  1.15it/s, loss=1.1268]
# 2026-04-12 10:15:42,068 - model.train - INFO - epoch 1 train_loss=1.1268 time=360.4s (6.0min)
# 2026-04-12 10:16:32,297 - model.train - INFO - val loss=1.1017 macro-F1=0.3322
# 2026-04-12 10:16:32,298 - model.train - INFO -   hygiene: 0.3201
# 2026-04-12 10:16:32,298 - model.train - INFO -   food: 0.3022
# 2026-04-12 10:16:32,299 - model.train - INFO -   hotel: 0.3139
# 2026-04-12 10:16:32,300 - model.train - INFO -   location: 0.2591
# 2026-04-12 10:16:32,301 - model.train - INFO -   room: 0.3762
# 2026-04-12 10:16:32,302 - model.train - INFO -   service: 0.4216
# 2026-04-12 10:16:33,352 - model.train - INFO - saved checkpoint macro-F1=0.3322 -> /kaggle/working/models/best.pt
# epoch 2/10:   0%|          | 0/414 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# epoch 2/10: 100%|██████████| 414/414 [06:07<00:00,  1.13it/s, loss=1.0031]
# 2026-04-12 10:22:40,860 - model.train - INFO - epoch 2 train_loss=1.0031 time=367.5s (6.1min)
# 2026-04-12 10:23:31,172 - model.train - INFO - val loss=1.0258 macro-F1=0.5118
# 2026-04-12 10:23:31,172 - model.train - INFO -   hygiene: 0.6877
# 2026-04-12 10:23:31,173 - model.train - INFO -   food: 0.3050
# 2026-04-12 10:23:31,173 - model.train - INFO -   hotel: 0.4317
# 2026-04-12 10:23:31,174 - model.train - INFO -   location: 0.2591
# 2026-04-12 10:23:31,174 - model.train - INFO -   room: 0.6301
# 2026-04-12 10:23:31,175 - model.train - INFO -   service: 0.7572
# 2026-04-12 10:23:32,757 - model.train - INFO - saved checkpoint macro-F1=0.5118 -> /kaggle/working/models/best.pt
# epoch 3/10:   0%|          | 0/414 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# epoch 3/10: 100%|██████████| 414/414 [06:06<00:00,  1.13it/s, loss=0.9166]
# 2026-04-12 10:29:39,514 - model.train - INFO - epoch 3 train_loss=0.9166 time=366.8s (6.1min)
# 2026-04-12 10:30:29,896 - model.train - INFO - val loss=0.9607 macro-F1=0.5714
# 2026-04-12 10:30:29,897 - model.train - INFO -   hygiene: 0.7299
# 2026-04-12 10:30:29,898 - model.train - INFO -   food: 0.3727
# 2026-04-12 10:30:29,898 - model.train - INFO -   hotel: 0.4325
# 2026-04-12 10:30:29,899 - model.train - INFO -   location: 0.4505
# 2026-04-12 10:30:29,900 - model.train - INFO -   room: 0.6993
# 2026-04-12 10:30:29,900 - model.train - INFO -   service: 0.7434
# 2026-04-12 10:30:31,453 - model.train - INFO - saved checkpoint macro-F1=0.5714 -> /kaggle/working/models/best.pt
# epoch 4/10:   0%|          | 0/414 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# epoch 4/10: 100%|██████████| 414/414 [06:07<00:00,  1.13it/s, loss=0.8561]
# 2026-04-12 10:36:38,882 - model.train - INFO - epoch 4 train_loss=0.8561 time=367.4s (6.1min)
# 2026-04-12 10:37:29,020 - model.train - INFO - val loss=0.9114 macro-F1=0.6202
# 2026-04-12 10:37:29,021 - model.train - INFO -   hygiene: 0.7818
# 2026-04-12 10:37:29,022 - model.train - INFO -   food: 0.4215
# 2026-04-12 10:37:29,022 - model.train - INFO -   hotel: 0.5232
# 2026-04-12 10:37:29,023 - model.train - INFO -   location: 0.5791
# 2026-04-12 10:37:29,023 - model.train - INFO -   room: 0.6432
# 2026-04-12 10:37:29,024 - model.train - INFO -   service: 0.7723
# 2026-04-12 10:37:30,589 - model.train - INFO - saved checkpoint macro-F1=0.6202 -> /kaggle/working/models/best.pt
# epoch 5/10:   0%|          | 0/414 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# epoch 5/10: 100%|██████████| 414/414 [06:06<00:00,  1.13it/s, loss=0.8126]
# 2026-04-12 10:43:37,155 - model.train - INFO - epoch 5 train_loss=0.8126 time=366.6s (6.1min)
# 2026-04-12 10:44:27,505 - model.train - INFO - val loss=0.8195 macro-F1=0.6852
# 2026-04-12 10:44:27,506 - model.train - INFO -   hygiene: 0.7907
# 2026-04-12 10:44:27,507 - model.train - INFO -   food: 0.6657
# 2026-04-12 10:44:27,508 - model.train - INFO -   hotel: 0.4844
# 2026-04-12 10:44:27,508 - model.train - INFO -   location: 0.6327
# 2026-04-12 10:44:27,509 - model.train - INFO -   room: 0.7480
# 2026-04-12 10:44:27,510 - model.train - INFO -   service: 0.7895
# 2026-04-12 10:44:29,105 - model.train - INFO - saved checkpoint macro-F1=0.6852 -> /kaggle/working/models/best.pt
# epoch 6/10:   0%|          | 0/414 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# epoch 6/10: 100%|██████████| 414/414 [06:07<00:00,  1.13it/s, loss=0.7718]
# 2026-04-12 10:50:36,190 - model.train - INFO - epoch 6 train_loss=0.7718 time=367.1s (6.1min)
# 2026-04-12 10:51:26,555 - model.train - INFO - val loss=0.8025 macro-F1=0.7104
# 2026-04-12 10:51:26,556 - model.train - INFO -   hygiene: 0.7894
# 2026-04-12 10:51:26,557 - model.train - INFO -   food: 0.7511
# 2026-04-12 10:51:26,557 - model.train - INFO -   hotel: 0.5188
# 2026-04-12 10:51:26,558 - model.train - INFO -   location: 0.6334
# 2026-04-12 10:51:26,558 - model.train - INFO -   room: 0.7807
# 2026-04-12 10:51:26,560 - model.train - INFO -   service: 0.7889
# 2026-04-12 10:51:28,161 - model.train - INFO - saved checkpoint macro-F1=0.7104 -> /kaggle/working/models/best.pt
# epoch 7/10:   0%|          | 0/414 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# epoch 7/10: 100%|██████████| 414/414 [06:06<00:00,  1.13it/s, loss=0.7481]
# 2026-04-12 10:57:34,714 - model.train - INFO - epoch 7 train_loss=0.7481 time=366.5s (6.1min)
# 2026-04-12 10:58:24,972 - model.train - INFO - val loss=0.7905 macro-F1=0.7236
# 2026-04-12 10:58:24,973 - model.train - INFO -   hygiene: 0.8045
# 2026-04-12 10:58:24,974 - model.train - INFO -   food: 0.7669
# 2026-04-12 10:58:24,974 - model.train - INFO -   hotel: 0.5001
# 2026-04-12 10:58:24,975 - model.train - INFO -   location: 0.6747
# 2026-04-12 10:58:24,976 - model.train - INFO -   room: 0.7928
# 2026-04-12 10:58:24,977 - model.train - INFO -   service: 0.8025
# 2026-04-12 10:58:26,607 - model.train - INFO - saved checkpoint macro-F1=0.7236 -> /kaggle/working/models/best.pt
# epoch 8/10:   0%|          | 0/414 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# epoch 8/10: 100%|██████████| 414/414 [06:06<00:00,  1.13it/s, loss=0.7317]
# 2026-04-12 11:04:33,303 - model.train - INFO - epoch 8 train_loss=0.7317 time=366.7s (6.1min)
# 2026-04-12 11:05:23,577 - model.train - INFO - val loss=0.7698 macro-F1=0.7428
# 2026-04-12 11:05:23,577 - model.train - INFO -   hygiene: 0.8080
# 2026-04-12 11:05:23,578 - model.train - INFO -   food: 0.7851
# 2026-04-12 11:05:23,579 - model.train - INFO -   hotel: 0.5451
# 2026-04-12 11:05:23,580 - model.train - INFO -   location: 0.7014
# 2026-04-12 11:05:23,580 - model.train - INFO -   room: 0.8052
# 2026-04-12 11:05:23,581 - model.train - INFO -   service: 0.8122
# 2026-04-12 11:05:25,132 - model.train - INFO - saved checkpoint macro-F1=0.7428 -> /kaggle/working/models/best.pt
# epoch 9/10:   0%|          | 0/414 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# epoch 9/10: 100%|██████████| 414/414 [06:06<00:00,  1.13it/s, loss=0.7190]
# 2026-04-12 11:11:31,582 - model.train - INFO - epoch 9 train_loss=0.7190 time=366.4s (6.1min)
# 2026-04-12 11:12:21,850 - model.train - INFO - val loss=0.7626 macro-F1=0.7505
# 2026-04-12 11:12:21,851 - model.train - INFO -   hygiene: 0.8051
# 2026-04-12 11:12:21,852 - model.train - INFO -   food: 0.7975
# 2026-04-12 11:12:21,853 - model.train - INFO -   hotel: 0.5507
# 2026-04-12 11:12:21,853 - model.train - INFO -   location: 0.7106
# 2026-04-12 11:12:21,854 - model.train - INFO -   room: 0.8175
# 2026-04-12 11:12:21,854 - model.train - INFO -   service: 0.8218
# 2026-04-12 11:12:23,482 - model.train - INFO - saved checkpoint macro-F1=0.7505 -> /kaggle/working/models/best.pt
# epoch 10/10:   0%|          | 0/414 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# epoch 10/10: 100%|██████████| 414/414 [06:07<00:00,  1.13it/s, loss=0.7106]
# 2026-04-12 11:18:31,244 - model.train - INFO - epoch 10 train_loss=0.7106 time=367.8s (6.1min)
# 2026-04-12 11:19:21,461 - model.train - INFO - val loss=0.7579 macro-F1=0.7557
# 2026-04-12 11:19:21,462 - model.train - INFO -   hygiene: 0.8088
# 2026-04-12 11:19:21,462 - model.train - INFO -   food: 0.7968
# 2026-04-12 11:19:21,463 - model.train - INFO -   hotel: 0.5687
# 2026-04-12 11:19:21,464 - model.train - INFO -   location: 0.7239
# 2026-04-12 11:19:21,464 - model.train - INFO -   room: 0.8199
# 2026-04-12 11:19:21,465 - model.train - INFO -   service: 0.8164
# 2026-04-12 11:19:23,037 - model.train - INFO - saved checkpoint macro-F1=0.7557 -> /kaggle/working/models/best.pt
# 2026-04-12 11:19:23,038 - model.train - INFO - done. best macro-F1=0.7557

# %%
import sys
sys.argv = ["evaluate.py",
            "--checkpoint", "/kaggle/working/models/best.pt",
            "--test-csv", "/kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_test.csv"]

from model.evaluate import main
main()
# Out:
# 2026-04-12 11:19:28,694 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 11:19:28,710 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/config.json "HTTP/1.1 200 OK"
# 2026-04-12 11:19:28,773 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 11:19:28,789 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-12 11:19:28,853 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-04-12 11:19:29,106 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-04-12 11:19:30,329 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base "HTTP/1.1 200 OK"
# 2026-04-12 11:19:30,341 - model.data - INFO - Loading reviews from: /kaggle/input/datasets/nguyenan2511/hotel-reviews-absa/crawl_only_test.csv
# 2026-04-12 11:19:30,368 - model.data - INFO - Loaded 1889 reviews
# 2026-04-12 11:19:30,886 - model.data - INFO - Pre-tokenized 1889 samples in 0.52s
# 2026-04-12 11:19:30,907 - model.hf_videberta - INFO - Loading model: Fsoft-AIC/videberta-base
# 2026-04-12 11:19:30,973 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-12 11:19:30,974 - huggingface_hub.utils._http - WARNING - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-12 11:19:30,990 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/config.json "HTTP/1.1 200 OK"
# 2026-04-12 11:19:31,065 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-12 11:19:31,080 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Fsoft-AIC/videberta-base/a27c8175098cc2b2b55585763fe26c60b117804c/config.json "HTTP/1.1 200 OK"
# 2026-04-12 11:19:31,181 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# 2026-04-12 11:19:31,247 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base "HTTP/1.1 200 OK"
# 2026-04-12 11:19:31,322 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/commits/main "HTTP/1.1 200 OK"
# 2026-04-12 11:19:31,399 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/discussions?p=0 "HTTP/1.1 200 OK"
# 2026-04-12 11:19:31,506 - httpx - INFO - HTTP Request: GET https://huggingface.co/api/models/Fsoft-AIC/videberta-base/commits/refs%2Fpr%2F1 "HTTP/1.1 200 OK"
# 2026-04-12 11:19:31,571 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/refs%2Fpr%2F1/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 2026-04-12 11:19:31,642 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/Fsoft-AIC/videberta-base/resolve/refs%2Fpr%2F1/model.safetensors "HTTP/1.1 302 Found"
# Loading weights:   0%|          | 0/198 [00:00<?, ?it/s]
# DebertaV2Model LOAD REPORT from: Fsoft-AIC/videberta-base
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# mask_predictions.LayerNorm.weight          | UNEXPECTED |  |
# mask_predictions.dense.weight              | UNEXPECTED |  |
# mask_predictions.classifier.weight         | UNEXPECTED |  |
# mask_predictions.LayerNorm.bias            | UNEXPECTED |  |
# deberta.embeddings.word_embeddings._weight | UNEXPECTED |  |
# mask_predictions.dense.bias                | UNEXPECTED |  |
# mask_predictions.classifier.bias           | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-04-12 11:19:32,096 - model.hf_videberta - INFO - Model loaded successfully
# 2026-04-12 11:19:32,695 - model.evaluate - WARNING - Missing keys in checkpoint: ['class_weights']
# 2026-04-12 11:19:32,699 - model.evaluate - INFO -
# --- Model Complexity ---
# 2026-04-12 11:19:32,700 - model.evaluate - INFO - Total parameters:      186,175,506
# 2026-04-12 11:19:32,700 - model.evaluate - INFO - Trainable parameters:    2,457,618  (1.3%)
# 2026-04-12 11:19:32,701 - model.evaluate - INFO - Frozen parameters:     183,717,888  (98.7%)
# 2026-04-12 11:19:32,702 - model.evaluate - INFO - Model size (est.):    710.2 MB (float32)
# 2026-04-12 11:20:17,832 - model.evaluate - INFO -
# Inference time total: 45.13s
# 2026-04-12 11:20:17,833 - model.evaluate - INFO - Inference time per sample: 23.89ms
# 2026-04-12 11:20:17,834 - model.evaluate - INFO - Per-aspect macro-F1 and accuracy:
# 2026-04-12 11:20:17,839 - model.evaluate - INFO -   hygiene: macro-F1=0.8193 acc=0.9164
# 2026-04-12 11:20:17,843 - model.evaluate - INFO -   food: macro-F1=0.7941 acc=0.9439
# 2026-04-12 11:20:17,847 - model.evaluate - INFO -   hotel: macro-F1=0.5496 acc=0.6675
# 2026-04-12 11:20:17,850 - model.evaluate - INFO -   location: macro-F1=0.7284 acc=0.9227
# 2026-04-12 11:20:17,853 - model.evaluate - INFO -   room: macro-F1=0.8135 acc=0.8671
# 2026-04-12 11:20:17,856 - model.evaluate - INFO -   service: macro-F1=0.8119 acc=0.9195
# 2026-04-12 11:20:17,857 - model.evaluate - INFO - Mean macro-F1 (over aspects): 0.7528
